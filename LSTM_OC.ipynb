# %%
import numpy as np
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
from sklearn.metrics import matthews_corrcoef
from mlxtend.evaluate import bias_variance_decomp
from tensorflow.keras.callbacks import EarlyStopping
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import os
import joblib
from keras.models import save_model
from keras.utils import plot_model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import RMSprop
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from keras.preprocessing import sequence
np.random.seed(7)
from keras.utils import pad_sequences
from sklearn.preprocessing import MinMaxScaler, LabelEncoder

from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 9681635400169006236
# xla_global_id: -1
# ]

# %%
X=[]
y=[]
base_path='dataset1/'
source_path=base_path
for child in os.listdir(source_path):
    sub_path = os.path.join(source_path, child)
    if os.path.isdir(sub_path):
        for data_file in os.listdir(sub_path):
            file_path = os.path.join(sub_path, data_file)
            print(file_path)
            data=pd.read_csv(file_path,header=None)
            print(data.shape)
            data=data.to_numpy()
            X.append(data)
            y.append(child)
# Out:
# dataset1/0/01+39.csv
# (30, 63)
# dataset1/0/8.csv
# (32, 63)
# dataset1/0/1-13.csv
# (32, 63)
# dataset1/0/01+73.csv
# (30, 63)
# dataset1/0/01-35.csv
# (30, 63)
# dataset1/0/01-87.csv
# (30, 63)
# dataset1/0/01+100.csv
# (29, 63)
# dataset1/0/1-12.csv
# (28, 63)
# dataset1/0/01+25.csv
# (35, 63)
# dataset1/0/002-1.csv
# (33, 63)
# dataset1/0/01+43.csv
# (33, 63)
# dataset1/0/01+101.csv
# (30, 63)
# dataset1/0/5.csv
# (32, 63)
# dataset1/0/4-4.csv
# (35, 63)
# dataset1/0/1-3.csv
# (28, 63)
# dataset1/0/2-2.csv
# (30, 63)
# dataset1/0/1-4.csv
# (35, 63)
# dataset1/0/002-17.csv
# (33, 63)
# dataset1/0/01+94.csv
# (30, 63)
# dataset1/0/01+155.csv
# (36, 63)
# dataset1/0/01+42.csv
# (30, 63)
# dataset1/0/002-5.csv
# (32, 63)
# dataset1/0/01+169.csv
# (32, 63)
# dataset1/0/13.csv
# (32, 63)
# dataset1/0/2+5.csv
# (32, 63)
# dataset1/0/01+131.csv
# (32, 63)
# dataset1/0/01-97.csv
# (30, 63)
# dataset1/0/3+17.csv
# (33, 63)
# dataset1/0/001+11.csv
# (36, 63)
# dataset1/0/01+97.csv
# (32, 63)
# dataset1/0/14.csv
# (31, 63)
# dataset1/0/002-6.csv
# (30, 63)
# dataset1/0/01+5.csv
# (35, 63)
# dataset1/0/01+128.csv
# (32, 63)
# dataset1/0/2-13.csv
# (32, 63)
# dataset1/0/01+140.csv
# (33, 63)
# dataset1/0/3+11.csv
# (36, 63)
# dataset1/0/01+65.csv
# (28, 63)
# dataset1/0/4-16.csv
# (30, 63)
# dataset1/0/004+19.csv
# (30, 63)
# dataset1/0/01+166.csv
# (30, 63)
# dataset1/0/01+48.csv
# (28, 63)
# dataset1/0/2-3.csv
# (28, 63)
# dataset1/0/01-44.csv
# (32, 63)
# dataset1/0/01+10.csv
# (29, 63)
# dataset1/0/2-5.csv
# (32, 63)
# dataset1/0/01+181.csv
# (33, 63)
# dataset1/0/01+112.csv
# (30, 63)
# dataset1/0/01+178.csv
# (31, 63)
# dataset1/0/01-66.csv
# (28, 63)
# dataset1/0/01+115.csv
# (33, 63)
# dataset1/0/1-17.csv
# (33, 63)
# dataset1/0/01+123.csv
# (28, 63)
# dataset1/0/002-9.csv
# (29, 63)
# dataset1/0/01+196.csv
# (30, 63)
# dataset1/0/01-93.csv
# (30, 63)
# dataset1/0/01+78.csv
# (30, 63)
# dataset1/0/01+195.csv
# (30, 63)
# dataset1/0/004+13.csv
# (32, 63)
# dataset1/0/01+2.csv
# (33, 63)
# dataset1/0/002+4.csv
# (35, 63)
# dataset1/0/01+134.csv
# (36, 63)
# dataset1/0/01+119.csv
# (30, 63)
# dataset1/0/4-9.csv
# (29, 63)
# dataset1/0/002-18.csv
# (30, 63)
# dataset1/0/01+168.csv
# (35, 63)
# dataset1/0/10.csv
# (30, 63)
# dataset1/0/01-4.csv
# (32, 63)
# dataset1/0/002+7.csv
# (33, 63)
# dataset1/0/01+108.csv
# (32, 63)
# dataset1/0/01+200.csv
# (42, 63)
# dataset1/0/01+96.csv
# (33, 63)
# dataset1/0/01+23.csv
# (30, 63)
# dataset1/0/01-5.csv
# (32, 63)
# dataset1/0/004+5.csv
# (32, 63)
# dataset1/0/9.csv
# (29, 63)
# dataset1/0/4-11.csv
# (36, 63)
# dataset1/0/001+17.csv
# (33, 63)
# dataset1/0/17.csv
# (33, 63)
# dataset1/0/01-88.csv
# (28, 63)
# dataset1/0/01-3.csv
# (35, 63)
# dataset1/0/002+15.csv
# (30, 63)
# dataset1/0/01+185.csv
# (32, 63)
# dataset1/0/01+33.csv
# (28, 63)
# dataset1/0/01-8.csv
# (31, 63)
# dataset1/0/01-28.csv
# (30, 63)
# dataset1/0/01-47.csv
# (36, 63)
# dataset1/0/01+51.csv
# (32, 63)
# dataset1/0/01+182.csv
# (30, 63)
# dataset1/0/01+52.csv
# (32, 63)
# dataset1/0/002+11.csv
# (36, 63)
# dataset1/0/002+14.csv
# (31, 63)
# dataset1/0/01+24.csv
# (28, 63)
# dataset1/0/3+7.csv
# (33, 63)
# dataset1/0/01-80.csv
# (30, 63)
# dataset1/0/01-29.csv
# (36, 63)
# dataset1/0/01-54.csv
# (30, 63)
# dataset1/0/01+142.csv
# (30, 63)
# dataset1/0/01+132.csv
# (29, 63)
# dataset1/0/01+11.csv
# (30, 63)
# dataset1/0/01-69.csv
# (30, 63)
# dataset1/0/01-68.csv
# (31, 63)
# dataset1/0/4-17.csv
# (33, 63)
# dataset1/0/01-32.csv
# (32, 63)
# dataset1/0/01+85.csv
# (30, 63)
# dataset1/0/01+194.csv
# (31, 63)
# dataset1/0/01-74.csv
# (32, 63)
# dataset1/0/1-11.csv
# (36, 63)
# dataset1/0/01+64.csv
# (36, 63)
# dataset1/0/01+172.csv
# (32, 63)
# dataset1/0/01+14.csv
# (32, 63)
# dataset1/0/1.csv
# (33, 63)
# dataset1/0/01+4.csv
# (28, 63)
# dataset1/0/3.csv
# (28, 63)
# dataset1/0/01+16.csv
# (30, 63)
# dataset1/0/01+163.csv
# (30, 63)
# dataset1/0/01-83.csv
# (32, 63)
# dataset1/0/01+129.csv
# (30, 63)
# dataset1/0/001+7.csv
# (33, 63)
# dataset1/0/01+27.csv
# (30, 63)
# dataset1/0/01-59.csv
# (30, 63)
# dataset1/0/01+53.csv
# (30, 63)
# dataset1/0/001+1.csv
# (33, 63)
# dataset1/0/01+74.csv
# (30, 63)
# dataset1/0/01+81.csv
# (42, 63)
# dataset1/0/01-48.csv
# (36, 63)
# dataset1/0/01-63.csv
# (30, 63)
# dataset1/0/2+19.csv
# (30, 63)
# dataset1/0/4-2.csv
# (30, 63)
# dataset1/0/01-39.csv
# (33, 63)
# dataset1/0/01+175.csv
# (36, 63)
# dataset1/0/01+84.csv
# (33, 63)
# dataset1/0/01+173.csv
# (29, 63)
# dataset1/0/002-10.csv
# (30, 63)
# dataset1/0/002+3.csv
# (28, 63)
# dataset1/0/01+86.csv
# (30, 63)
# dataset1/0/01+109.csv
# (31, 63)
# dataset1/0/01-100.csv
# (42, 63)
# dataset1/0/6.csv
# (30, 63)
# dataset1/0/01-52.csv
# (30, 63)
# dataset1/0/01-38.csv
# (42, 63)
# dataset1/0/01+55.csv
# (33, 63)
# dataset1/0/3+1.csv
# (33, 63)
# dataset1/0/2-14.csv
# (31, 63)
# dataset1/0/01-50.csv
# (31, 63)
# dataset1/0/01-75.csv
# (29, 63)
# dataset1/0/001+6.csv
# (30, 63)
# dataset1/0/01+50.csv
# (35, 63)
# dataset1/0/01-94.csv
# (33, 63)
# dataset1/0/002-3.csv
# (28, 63)
# dataset1/0/2+1.csv
# (33, 63)
# dataset1/0/01-26.csv
# (33, 63)
# dataset1/0/01+171.csv
# (33, 63)
# dataset1/0/3+10.csv
# (30, 63)
# dataset1/0/1-14.csv
# (31, 63)
# dataset1/0/002-15.csv
# (30, 63)
# dataset1/0/01+188.csv
# (32, 63)
# dataset1/0/2+10.csv
# (30, 63)
# dataset1/0/01-10.csv
# (30, 63)
# dataset1/0/01+45.csv
# (30, 63)
# dataset1/0/004+7.csv
# (33, 63)
# dataset1/0/1-18.csv
# (30, 63)
# dataset1/0/01-84.csv
# (30, 63)
# dataset1/0/002+13.csv
# (32, 63)
# dataset1/0/01+187.csv
# (33, 63)
# dataset1/0/01+118.csv
# (30, 63)
# dataset1/0/01-31.csv
# (28, 63)
# dataset1/0/004+11.csv
# (36, 63)
# dataset1/0/01+177.csv
# (32, 63)
# dataset1/0/01+35.csv
# (31, 63)
# dataset1/0/01+135.csv
# (28, 63)
# dataset1/0/1-19.csv
# (30, 63)
# dataset1/0/01+61.csv
# (30, 63)
# dataset1/0/01-25.csv
# (30, 63)
# dataset1/0/01+44.csv
# (33, 63)
# dataset1/0/002+8.csv
# (32, 63)
# dataset1/0/2+2.csv
# (30, 63)
# dataset1/0/002-2.csv
# (30, 63)
# dataset1/0/01-62.csv
# (32, 63)
# dataset1/0/01+56.csv
# (33, 63)
# dataset1/0/01+102.csv
# (30, 63)
# dataset1/0/004+6.csv
# (30, 63)
# dataset1/0/004+4.csv
# (35, 63)
# dataset1/0/002+17.csv
# (33, 63)
# dataset1/0/2+8.csv
# (32, 63)
# dataset1/0/01+167.csv
# (28, 63)
# dataset1/0/01+91.csv
# (32, 63)
# dataset1/0/3+20.csv
# (42, 63)
# dataset1/0/2-12.csv
# (28, 63)
# dataset1/0/01+105.csv
# (28, 63)
# dataset1/0/2-7.csv
# (33, 63)
# dataset1/0/01+34.csv
# (32, 63)
# dataset1/0/01+170.csv
# (30, 63)
# dataset1/0/001+18.csv
# (30, 63)
# dataset1/0/01-12.csv
# (33, 63)
# dataset1/0/001+12.csv
# (28, 63)
# dataset1/0/4-3.csv
# (28, 63)
# dataset1/0/01+164.csv
# (42, 63)
# dataset1/0/3+18.csv
# (30, 63)
# dataset1/0/01+71.csv
# (30, 63)
# dataset1/0/01+46.csv
# (30, 63)
# dataset1/0/01+54.csv
# (30, 63)
# dataset1/0/01+49.csv
# (35, 63)
# dataset1/0/01+144.csv
# (35, 63)
# dataset1/0/01+92.csv
# (32, 63)
# dataset1/0/1-8.csv
# (32, 63)
# dataset1/0/01+89.csv
# (35, 63)
# dataset1/0/004+12.csv
# (28, 63)
# dataset1/0/001+20.csv
# (42, 63)
# dataset1/0/3+19.csv
# (30, 63)
# dataset1/0/01+15.csv
# (31, 63)
# dataset1/0/01+79.csv
# (30, 63)
# dataset1/0/01-85.csv
# (33, 63)
# dataset1/0/002+20.csv
# (42, 63)
# dataset1/0/004+3.csv
# (28, 63)
# dataset1/0/01+133.csv
# (30, 63)
# dataset1/0/01+192.csv
# (28, 63)
# dataset1/0/4-20.csv
# (42, 63)
# dataset1/0/01-60.csv
# (28, 63)
# dataset1/0/01-20.csv
# (30, 63)
# dataset1/0/01+18.csv
# (33, 63)
# dataset1/0/01-95.csv
# (36, 63)
# dataset1/0/01-24.csv
# (30, 63)
# dataset1/0/01+9.csv
# (32, 63)
# dataset1/0/004+15.csv
# (30, 63)
# dataset1/0/01+57.csv
# (32, 63)
# dataset1/0/01+111.csv
# (30, 63)
# dataset1/0/01-2.csv
# (28, 63)
# dataset1/0/01+141.csv
# (30, 63)
# dataset1/0/01+98.csv
# (32, 63)
# dataset1/0/18.csv
# (30, 63)
# dataset1/0/01+106.csv
# (28, 63)
# dataset1/0/01-91.csv
# (30, 63)
# dataset1/0/3+14.csv
# (31, 63)
# dataset1/0/01+150.csv
# (30, 63)
# dataset1/0/01+125.csv
# (30, 63)
# dataset1/0/01+82.csv
# (42, 63)
# dataset1/0/4-10.csv
# (30, 63)
# dataset1/0/2+9.csv
# (29, 63)
# dataset1/0/2+17.csv
# (33, 63)
# dataset1/0/01+19.csv
# (30, 63)
# dataset1/0/4-6.csv
# (30, 63)
# dataset1/0/002+5.csv
# (32, 63)
# dataset1/0/2+16.csv
# (30, 63)
# dataset1/0/01-37.csv
# (30, 63)
# dataset1/0/01-96.csv
# (28, 63)
# dataset1/0/01+186.csv
# (30, 63)
# dataset1/0/001+9.csv
# (29, 63)
# dataset1/0/01-23.csv
# (35, 63)
# dataset1/0/01-40.csv
# (35, 63)
# dataset1/0/2+3.csv
# (28, 63)
# dataset1/0/01-57.csv
# (42, 63)
# dataset1/0/01+161.csv
# (33, 63)
# dataset1/0/3+13.csv
# (32, 63)
# dataset1/0/01+138.csv
# (30, 63)
# dataset1/0/01-17.csv
# (30, 63)
# dataset1/0/002+18.csv
# (30, 63)
# dataset1/0/1-2.csv
# (30, 63)
# dataset1/0/01-9.csv
# (30, 63)
# dataset1/0/01+110.csv
# (31, 63)
# dataset1/0/3+6.csv
# (30, 63)
# dataset1/0/01-82.csv
# (33, 63)
# dataset1/0/01-33.csv
# (31, 63)
# dataset1/0/01+6.csv
# (32, 63)
# dataset1/0/01-58.csv
# (42, 63)
# dataset1/0/2-16.csv
# (30, 63)
# dataset1/0/002-12.csv
# (28, 63)
# dataset1/0/01-86.csv
# (32, 63)
# dataset1/0/1-7.csv
# (33, 63)
# dataset1/0/01+17.csv
# (30, 63)
# dataset1/0/3+3.csv
# (28, 63)
# dataset1/0/01-27.csv
# (29, 63)
# dataset1/0/01+197.csv
# (33, 63)
# dataset1/0/004+16.csv
# (30, 63)
# dataset1/0/002-7.csv
# (33, 63)
# dataset1/0/3+9.csv
# (29, 63)
# dataset1/0/01-13.csv
# (32, 63)
# dataset1/0/002+19.csv
# (30, 63)
# dataset1/0/01+68.csv
# (32, 63)
# dataset1/0/002-8.csv
# (32, 63)
# dataset1/0/001+5.csv
# (32, 63)
# dataset1/0/01+145.csv
# (33, 63)
# dataset1/0/002-4.csv
# (35, 63)
# dataset1/0/002-13.csv
# (32, 63)
# dataset1/0/01+148.csv
# (35, 63)
# dataset1/0/01-77.csv
# (31, 63)
# dataset1/0/01+151.csv
# (33, 63)
# dataset1/0/01-78.csv
# (30, 63)
# dataset1/0/01+58.csv
# (32, 63)
# dataset1/0/01+157.csv
# (32, 63)
# dataset1/0/01+88.csv
# (28, 63)
# dataset1/0/01+26.csv
# (32, 63)
# dataset1/0/01-19.csv
# (42, 63)
# dataset1/0/01+107.csv
# (32, 63)
# dataset1/0/01+143.csv
# (42, 63)
# dataset1/0/4-12.csv
# (28, 63)
# dataset1/0/001+19.csv
# (30, 63)
# dataset1/0/01-42.csv
# (30, 63)
# dataset1/0/4-13.csv
# (32, 63)
# dataset1/0/01+160.csv
# (30, 63)
# dataset1/0/01+130.csv
# (33, 63)
# dataset1/0/01+121.csv
# (42, 63)
# dataset1/0/01-99.csv
# (30, 63)
# dataset1/0/002-16.csv
# (30, 63)
# dataset1/0/01-79.csv
# (33, 63)
# dataset1/0/002+2.csv
# (30, 63)
# dataset1/0/01-90.csv
# (31, 63)
# dataset1/0/01+63.csv
# (36, 63)
# dataset1/0/2-8.csv
# (32, 63)
# dataset1/0/01+180.csv
# (30, 63)
# dataset1/0/01+70.csv
# (31, 63)
# dataset1/0/01-16.csv
# (30, 63)
# dataset1/0/3+4.csv
# (35, 63)
# dataset1/0/001+16.csv
# (30, 63)
# dataset1/0/01+13.csv
# (28, 63)
# dataset1/0/2-4.csv
# (35, 63)
# dataset1/0/4-1.csv
# (33, 63)
# dataset1/0/01+30.csv
# (29, 63)
# dataset1/0/01+20.csv
# (30, 63)
# dataset1/0/7.csv
# (33, 63)
# dataset1/0/004+14.csv
# (31, 63)
# dataset1/0/01+198.csv
# (30, 63)
# dataset1/0/001+13.csv
# (32, 63)
# dataset1/0/004+2.csv
# (30, 63)
# dataset1/0/01+190.csv
# (30, 63)
# dataset1/0/01+184.csv
# (42, 63)
# dataset1/0/1-5.csv
# (32, 63)
# dataset1/0/01-18.csv
# (30, 63)
# dataset1/0/002-20.csv
# (42, 63)
# dataset1/0/002+9.csv
# (29, 63)
# dataset1/0/1-15.csv
# (30, 63)
# dataset1/0/01-36.csv
# (30, 63)
# dataset1/0/002+16.csv
# (30, 63)
# dataset1/0/001+3.csv
# (28, 63)
# dataset1/0/01+113.csv
# (30, 63)
# dataset1/0/01+87.csv
# (28, 63)
# dataset1/0/01-55.csv
# (30, 63)
# dataset1/0/01-92.csv
# (30, 63)
# dataset1/0/001+15.csv
# (30, 63)
# dataset1/0/01+8.csv
# (33, 63)
# dataset1/0/3+8.csv
# (32, 63)
# dataset1/0/01+153.csv
# (29, 63)
# dataset1/0/01-81.csv
# (42, 63)
# dataset1/0/002+10.csv
# (30, 63)
# dataset1/0/01+122.csv
# (42, 63)
# dataset1/0/01+38.csv
# (33, 63)
# dataset1/0/004+8.csv
# (32, 63)
# dataset1/0/01-64.csv
# (32, 63)
# dataset1/0/01+21.csv
# (42, 63)
# dataset1/0/2-15.csv
# (30, 63)
# dataset1/0/002+6.csv
# (30, 63)
# dataset1/0/01+191.csv
# (36, 63)
# dataset1/0/01+104.csv
# (36, 63)
# dataset1/0/2+14.csv
# (31, 63)
# dataset1/0/01-72.csv
# (33, 63)
# dataset1/0/01+162.csv
# (30, 63)
# dataset1/0/01+80.csv
# (30, 63)
# dataset1/0/2-20.csv
# (42, 63)
# dataset1/0/2-1.csv
# (33, 63)
# dataset1/0/001+14.csv
# (31, 63)
# dataset1/0/1-16.csv
# (30, 63)
# dataset1/0/01-76.csv
# (30, 63)
# dataset1/0/01-30.csv
# (28, 63)
# dataset1/0/2+7.csv
# (33, 63)
# dataset1/0/004+18.csv
# (30, 63)
# dataset1/0/01+149.csv
# (32, 63)
# dataset1/0/01-67.csv
# (32, 63)
# dataset1/0/01-41.csv
# (35, 63)
# dataset1/0/2+11.csv
# (36, 63)
# dataset1/0/01+199.csv
# (30, 63)
# dataset1/0/001+10.csv
# (30, 63)
# dataset1/0/4-8.csv
# (32, 63)
# dataset1/0/01+77.csv
# (30, 63)
# dataset1/0/01+179.csv
# (30, 63)
# dataset1/0/01-46.csv
# (30, 63)
# dataset1/0/16.csv
# (30, 63)
# dataset1/0/01+103.csv
# (36, 63)
# dataset1/0/01+36.csv
# (30, 63)
# dataset1/0/01-51.csv
# (30, 63)
# dataset1/0/3+2.csv
# (30, 63)
# dataset1/0/01-65.csv
# (29, 63)
# dataset1/0/01+69.csv
# (31, 63)
# dataset1/0/01+28.csv
# (33, 63)
# dataset1/0/01+159.csv
# (30, 63)
# dataset1/0/4-7.csv
# (33, 63)
# dataset1/0/1-20.csv
# (42, 63)
# dataset1/0/01-21.csv
# (33, 63)
# dataset1/0/2-10.csv
# (30, 63)
# dataset1/0/01+136.csv
# (32, 63)
# dataset1/0/2.csv
# (30, 63)
# dataset1/0/01+90.csv
# (35, 63)
# dataset1/0/01-34.csv
# (30, 63)
# dataset1/0/1-1.csv
# (33, 63)
# dataset1/0/3+12.csv
# (28, 63)
# dataset1/0/01+93.csv
# (30, 63)
# dataset1/0/01-70.csv
# (30, 63)
# dataset1/0/15.csv
# (30, 63)
# dataset1/0/01+146.csv
# (30, 63)
# dataset1/0/01+40.csv
# (30, 63)
# dataset1/0/01+193.csv
# (32, 63)
# dataset1/0/01-11.csv
# (30, 63)
# dataset1/0/01-1.csv
# (30, 63)
# dataset1/0/01+139.csv
# (30, 63)
# dataset1/0/004+9.csv
# (29, 63)
# dataset1/0/01+126.csv
# (28, 63)
# dataset1/0/2-19.csv
# (30, 63)
# dataset1/0/4.csv
# (35, 63)
# dataset1/0/01+95.csv
# (33, 63)
# dataset1/0/004+20.csv
# (42, 63)
# dataset1/0/2+13.csv
# (32, 63)
# dataset1/0/4-19.csv
# (30, 63)
# dataset1/0/01+62.csv
# (30, 63)
# dataset1/0/01+83.csv
# (33, 63)
# dataset1/0/2+4.csv
# (35, 63)
# dataset1/0/2-11.csv
# (36, 63)
# dataset1/0/1-6.csv
# (30, 63)
# dataset1/0/01+124.csv
# (33, 63)
# dataset1/0/01+137.csv
# (31, 63)
# dataset1/0/01+114.csv
# (30, 63)
# dataset1/0/01+156.csv
# (28, 63)
# dataset1/0/11.csv
# (36, 63)
# dataset1/0/01+12.csv
# (36, 63)
# dataset1/0/01-89.csv
# (32, 63)
# dataset1/0/2-17.csv
# (33, 63)
# dataset1/0/002+12.csv
# (28, 63)
# dataset1/0/01+7.csv
# (30, 63)
# dataset1/0/01+183.csv
# (30, 63)
# dataset1/0/01+22.csv
# (33, 63)
# dataset1/0/004+1.csv
# (33, 63)
# dataset1/0/2-9.csv
# (29, 63)
# dataset1/0/01+31.csv
# (30, 63)
# dataset1/0/1-10.csv
# (30, 63)
# dataset1/0/2-6.csv
# (30, 63)
# dataset1/0/01-98.csv
# (30, 63)
# dataset1/0/4-15.csv
# (30, 63)
# dataset1/0/2+20.csv
# (42, 63)
# dataset1/0/12.csv
# (28, 63)
# dataset1/0/4-18.csv
# (30, 63)
# dataset1/0/001+4.csv
# (35, 63)
# dataset1/0/2+6.csv
# (30, 63)
# dataset1/0/004+17.csv
# (33, 63)
# dataset1/0/01+116.csv
# (33, 63)
# dataset1/0/01+189.csv
# (29, 63)
# dataset1/0/01+147.csv
# (28, 63)
# dataset1/0/01-56.csv
# (30, 63)
# dataset1/0/01+127.csv
# (35, 63)
# dataset1/0/01+60.csv
# (29, 63)
# dataset1/0/01+72.csv
# (30, 63)
# dataset1/0/01+117.csv
# (30, 63)
# dataset1/0/01+59.csv
# (29, 63)
# dataset1/0/01-43.csv
# (32, 63)
# dataset1/0/01+3.csv
# (30, 63)
# dataset1/0/002-19.csv
# (30, 63)
# dataset1/0/01+99.csv
# (29, 63)
# dataset1/0/01-6.csv
# (30, 63)
# dataset1/0/01-22.csv
# (30, 63)
# dataset1/0/01+29.csv
# (32, 63)
# dataset1/0/2+18.csv
# (30, 63)
# dataset1/0/01+41.csv
# (42, 63)
# dataset1/0/01+66.csv
# (28, 63)
# dataset1/0/01+120.csv
# (30, 63)
# dataset1/0/002-14.csv
# (31, 63)
# dataset1/0/3+16.csv
# (30, 63)
# dataset1/0/01+174.csv
# (30, 63)
# dataset1/0/2-18.csv
# (30, 63)
# dataset1/0/01+37.csv
# (30, 63)
# dataset1/0/01-73.csv
# (30, 63)
# dataset1/0/01+165.csv
# (33, 63)
# dataset1/0/1-9.csv
# (29, 63)
# dataset1/0/01+32.csv
# (36, 63)
# dataset1/0/004+10.csv
# (30, 63)
# dataset1/0/01-45.csv
# (29, 63)
# dataset1/0/01-53.csv
# (33, 63)
# dataset1/0/20.csv
# (42, 63)
# dataset1/0/01+158.csv
# (31, 63)
# dataset1/0/01+1.csv
# (33, 63)
# dataset1/0/001+2.csv
# (30, 63)
# dataset1/0/01-15.csv
# (29, 63)
# dataset1/0/01-14.csv
# (30, 63)
# dataset1/0/4-14.csv
# (31, 63)
# dataset1/0/001+8.csv
# (32, 63)
# dataset1/0/19.csv
# (30, 63)
# dataset1/0/002+1.csv
# (33, 63)
# dataset1/0/002-11.csv
# (36, 63)
# dataset1/0/01-49.csv
# (32, 63)
# dataset1/0/01+76.csv
# (33, 63)
# dataset1/0/01+154.csv
# (30, 63)
# dataset1/0/01+176.csv
# (28, 63)
# dataset1/0/2+12.csv
# (28, 63)
# dataset1/0/4-5.csv
# (32, 63)
# dataset1/0/01-71.csv
# (35, 63)
# dataset1/0/3+5.csv
# (32, 63)
# dataset1/0/01+152.csv
# (32, 63)
# dataset1/0/2+15.csv
# (30, 63)
# dataset1/0/3+15.csv
# (30, 63)
# dataset1/0/01+75.csv
# (33, 63)
# dataset1/0/01-7.csv
# (32, 63)
# dataset1/0/01-61.csv
# (35, 63)
# dataset1/0/01+67.csv
# (32, 63)
# dataset1/0/01+47.csv
# (28, 63)
# dataset1/1/002+62.csv
# (37, 63)
# dataset1/1/002+169.csv
# (46, 63)
# dataset1/1/001+47.csv
# (54, 63)
# dataset1/1/002+84.csv
# (49, 63)
# dataset1/1/001+97.csv
# (57, 63)
# dataset1/1/002+25.csv
# (52, 63)
# dataset1/1/002+175.csv
# (52, 63)
# dataset1/1/002+131.csv
# (47, 63)
# dataset1/1/002+43.csv
# (43, 63)
# dataset1/1/001+108.csv
# (42, 63)
# dataset1/1/002+179.csv
# (53, 63)
# dataset1/1/002+35.csv
# (48, 63)
# dataset1/1/no-5.csv
# (40, 63)
# dataset1/1/002+184.csv
# (49, 63)
# dataset1/1/002+114.csv
# (46, 63)
# dataset1/1/002-1.csv
# (38, 63)
# dataset1/1/5.csv
# (42, 63)
# dataset1/1/001+64.csv
# (52, 63)
# dataset1/1/100.csv
# (46, 63)
# dataset1/1/002+115.csv
# (47, 63)
# dataset1/1/45.csv
# (37, 63)
# dataset1/1/001+66.csv
# (44, 63)
# dataset1/1/002+152.csv
# (46, 63)
# dataset1/1/001-5.csv
# (40, 63)
# dataset1/1/002-5.csv
# (40, 63)
# dataset1/1/13.csv
# (47, 63)
# dataset1/1/001+11.csv
# (42, 63)
# dataset1/1/001+84.csv
# (44, 63)
# dataset1/1/14.csv
# (47, 63)
# dataset1/1/002-6.csv
# (40, 63)
# dataset1/1/58.csv
# (52, 63)
# dataset1/1/92.csv
# (52, 63)
# dataset1/1/002+212.csv
# (50, 63)
# dataset1/1/004-1.csv
# (38, 63)
# dataset1/1/002+110.csv
# (45, 63)
# dataset1/1/001+75.csv
# (52, 63)
# dataset1/1/95.csv
# (50, 63)
# dataset1/1/002+129.csv
# (47, 63)
# dataset1/1/001+38.csv
# (46, 63)
# dataset1/1/55.csv
# (49, 63)
# dataset1/1/0001-11.csv
# (38, 63)
# dataset1/1/86.csv
# (47, 63)
# dataset1/1/73.csv
# (46, 63)
# dataset1/1/002+90.csv
# (46, 63)
# dataset1/1/54.csv
# (34, 63)
# dataset1/1/48.csv
# (52, 63)
# dataset1/1/002+132.csv
# (47, 63)
# dataset1/1/91.csv
# (41, 63)
# dataset1/1/002+122.csv
# (42, 63)
# dataset1/1/002-9.csv
# (38, 63)
# dataset1/1/002+72.csv
# (49, 63)
# dataset1/1/001+70.csv
# (52, 63)
# dataset1/1/002+85.csv
# (52, 63)
# dataset1/1/42.csv
# (37, 63)
# dataset1/1/24.csv
# (43, 63)
# dataset1/1/002+74.csv
# (52, 63)
# dataset1/1/002+127.csv
# (52, 63)
# dataset1/1/002+4.csv
# (39, 63)
# dataset1/1/001+71.csv
# (43, 63)
# dataset1/1/004-8.csv
# (39, 63)
# dataset1/1/ne-8.csv
# (52, 63)
# dataset1/1/84.csv
# (49, 63)
# dataset1/1/002+98.csv
# (45, 63)
# dataset1/1/63.csv
# (52, 63)
# dataset1/1/004-5.csv
# (40, 63)
# dataset1/1/001+26.csv
# (48, 63)
# dataset1/1/75.csv
# (53, 63)
# dataset1/1/10.csv
# (52, 63)
# dataset1/1/001+104.csv
# (46, 63)
# dataset1/1/001+48.csv
# (37, 63)
# dataset1/1/002+7.csv
# (43, 63)
# dataset1/1/0001-16.csv
# (40, 63)
# dataset1/1/001+91.csv
# (49, 63)
# dataset1/1/93.csv
# (45, 63)
# dataset1/1/002+190.csv
# (46, 63)
# dataset1/1/002+199.csv
# (54, 63)
# dataset1/1/002+124.csv
# (42, 63)
# dataset1/1/9.csv
# (52, 63)
# dataset1/1/001+17.csv
# (52, 63)
# dataset1/1/17.csv
# (48, 63)
# dataset1/1/002+121.csv
# (42, 63)
# dataset1/1/002+15.csv
# (40, 63)
# dataset1/1/001+81.csv
# (45, 63)
# dataset1/1/001+39.csv
# (46, 63)
# dataset1/1/002+11.csv
# (38, 63)
# dataset1/1/002+14.csv
# (39, 63)
# dataset1/1/001+80.csv
# (46, 63)
# dataset1/1/001+92.csv
# (50, 63)
# dataset1/1/001+51.csv
# (37, 63)
# dataset1/1/002+148.csv
# (46, 63)
# dataset1/1/00-8.csv
# (39, 63)
# dataset1/1/002+213.csv
# (43, 63)
# dataset1/1/47.csv
# (52, 63)
# dataset1/1/001+31.csv
# (43, 63)
# dataset1/1/002+202.csv
# (50, 63)
# dataset1/1/001+49.csv
# (37, 63)
# dataset1/1/002+116.csv
# (46, 63)
# dataset1/1/3.csv
# (42, 63)
# dataset1/1/002+160.csv
# (37, 63)
# dataset1/1/001+7.csv
# (43, 63)
# dataset1/1/00-1.csv
# (38, 63)
# dataset1/1/001+1.csv
# (38, 63)
# dataset1/1/001+69.csv
# (53, 63)
# dataset1/1/002+197.csv
# (34, 63)
# dataset1/1/002+77.csv
# (45, 63)
# dataset1/1/001+35.csv
# (43, 63)
# dataset1/1/001-2.csv
# (36, 63)
# dataset1/1/001+60.csv
# (51, 63)
# dataset1/1/002+174.csv
# (52, 63)
# dataset1/1/002-10.csv
# (46, 63)
# dataset1/1/002+170.csv
# (51, 63)
# dataset1/1/002+3.csv
# (38, 63)
# dataset1/1/no-8.csv
# (39, 63)
# dataset1/1/90.csv
# (57, 63)
# dataset1/1/6.csv
# (52, 63)
# dataset1/1/0001-8.csv
# (39, 63)
# dataset1/1/002+143.csv
# (43, 63)
# dataset1/1/002+76.csv
# (44, 63)
# dataset1/1/001+68.csv
# (45, 63)
# dataset1/1/001+73.csv
# (43, 63)
# dataset1/1/74.csv
# (45, 63)
# dataset1/1/002+112.csv
# (50, 63)
# dataset1/1/002+111.csv
# (50, 63)
# dataset1/1/002+60.csv
# (37, 63)
# dataset1/1/002+49.csv
# (46, 63)
# dataset1/1/001+32.csv
# (43, 63)
# dataset1/1/001+89.csv
# (54, 63)
# dataset1/1/65.csv
# (46, 63)
# dataset1/1/31.csv
# (46, 63)
# dataset1/1/001+6.csv
# (40, 63)
# dataset1/1/no-7.csv
# (43, 63)
# dataset1/1/002+113.csv
# (43, 63)
# dataset1/1/002+28.csv
# (47, 63)
# dataset1/1/002+216.csv
# (46, 63)
# dataset1/1/no-9.csv
# (38, 63)
# dataset1/1/29.csv
# (43, 63)
# dataset1/1/001+105.csv
# (47, 63)
# dataset1/1/001+54.csv
# (52, 63)
# dataset1/1/002-3.csv
# (38, 63)
# dataset1/1/002+217.csv
# (46, 63)
# dataset1/1/69.csv
# (35, 63)
# dataset1/1/002+29.csv
# (47, 63)
# dataset1/1/001+93.csv
# (47, 63)
# dataset1/1/002+191.csv
# (45, 63)
# dataset1/1/66.csv
# (43, 63)
# dataset1/1/002+97.csv
# (34, 63)
# dataset1/1/002+183.csv
# (43, 63)
# dataset1/1/001+21.csv
# (47, 63)
# dataset1/1/002+47.csv
# (43, 63)
# dataset1/1/001-7.csv
# (43, 63)
# dataset1/1/002+13.csv
# (38, 63)
# dataset1/1/28.csv
# (43, 63)
# dataset1/1/52.csv
# (46, 63)
# dataset1/1/002+162.csv
# (37, 63)
# dataset1/1/002+52.csv
# (46, 63)
# dataset1/1/001+99.csv
# (52, 63)
# dataset1/1/no-10.csv
# (46, 63)
# dataset1/1/82.csv
# (54, 63)
# dataset1/1/002+96.csv
# (48, 63)
# dataset1/1/002+215.csv
# (47, 63)
# dataset1/1/002+135.csv
# (48, 63)
# dataset1/1/002+89.csv
# (45, 63)
# dataset1/1/002+101.csv
# (49, 63)
# dataset1/1/26.csv
# (43, 63)
# dataset1/1/002+8.csv
# (39, 63)
# dataset1/1/001-9.csv
# (38, 63)
# dataset1/1/002+182.csv
# (46, 63)
# dataset1/1/002+27.csv
# (52, 63)
# dataset1/1/004-4.csv
# (39, 63)
# dataset1/1/002+164.csv
# (52, 63)
# dataset1/1/002-2.csv
# (36, 63)
# dataset1/1/001+78.csv
# (39, 63)
# dataset1/1/002+17.csv
# (43, 63)
# dataset1/1/32.csv
# (46, 63)
# dataset1/1/002+59.csv
# (37, 63)
# dataset1/1/002+218.csv
# (42, 63)
# dataset1/1/001+50.csv
# (37, 63)
# dataset1/1/002+118.csv
# (42, 63)
# dataset1/1/43.csv
# (37, 63)
# dataset1/1/002+36.csv
# (48, 63)
# dataset1/1/001+58.csv
# (40, 63)
# dataset1/1/002+156.csv
# (54, 63)
# dataset1/1/001+18.csv
# (47, 63)
# dataset1/1/002+56.csv
# (54, 63)
# dataset1/1/0001-13.csv
# (38, 63)
# dataset1/1/001+12.csv
# (42, 63)
# dataset1/1/001+87.csv
# (34, 63)
# dataset1/1/002+165.csv
# (52, 63)
# dataset1/1/002+106.csv
# (52, 63)
# dataset1/1/002+108.csv
# (41, 63)
# dataset1/1/002+205.csv
# (50, 63)
# dataset1/1/62.csv
# (53, 63)
# dataset1/1/72.csv
# (45, 63)
# dataset1/1/001+33.csv
# (43, 63)
# dataset1/1/004-7.csv
# (43, 63)
# dataset1/1/001+20.csv
# (47, 63)
# dataset1/1/001+43.csv
# (54, 63)
# dataset1/1/001+25.csv
# (48, 63)
# dataset1/1/0001-1.csv
# (38, 63)
# dataset1/1/40.csv
# (54, 63)
# dataset1/1/002+83.csv
# (43, 63)
# dataset1/1/002+219.csv
# (52, 63)
# dataset1/1/ne-1.csv
# (42, 63)
# dataset1/1/002+20.csv
# (46, 63)
# dataset1/1/002+46.csv
# (43, 63)
# dataset1/1/78.csv
# (54, 63)
# dataset1/1/002+201.csv
# (49, 63)
# dataset1/1/002+208.csv
# (41, 63)
# dataset1/1/0001-15.csv
# (40, 63)
# dataset1/1/002+67.csv
# (52, 63)
# dataset1/1/002+126.csv
# (52, 63)
# dataset1/1/001+98.csv
# (41, 63)
# dataset1/1/001+82.csv
# (53, 63)
# dataset1/1/002+44.csv
# (43, 63)
# dataset1/1/18.csv
# (48, 63)
# dataset1/1/0001-14.csv
# (39, 63)
# dataset1/1/002+93.csv
# (52, 63)
# dataset1/1/001-1.csv
# (38, 63)
# dataset1/1/00-7.csv
# (43, 63)
# dataset1/1/001+74.csv
# (49, 63)
# dataset1/1/00-5.csv
# (40, 63)
# dataset1/1/001+30.csv
# (43, 63)
# dataset1/1/46.csv
# (52, 63)
# dataset1/1/001+106.csv
# (46, 63)
# dataset1/1/70.csv
# (48, 63)
# dataset1/1/002+211.csv
# (50, 63)
# dataset1/1/0001-6.csv
# (40, 63)
# dataset1/1/001+42.csv
# (46, 63)
# dataset1/1/002+33.csv
# (48, 63)
# dataset1/1/001+37.csv
# (43, 63)
# dataset1/1/002+99.csv
# (54, 63)
# dataset1/1/002+68.csv
# (40, 63)
# dataset1/1/89.csv
# (52, 63)
# dataset1/1/002+69.csv
# (46, 63)
# dataset1/1/41.csv
# (37, 63)
# dataset1/1/0001-4.csv
# (39, 63)
# dataset1/1/002+203.csv
# (47, 63)
# dataset1/1/30.csv
# (43, 63)
# dataset1/1/001-6.csv
# (40, 63)
# dataset1/1/002+5.csv
# (40, 63)
# dataset1/1/001+61.csv
# (34, 63)
# dataset1/1/002+34.csv
# (48, 63)
# dataset1/1/002+53.csv
# (54, 63)
# dataset1/1/001+9.csv
# (38, 63)
# dataset1/1/001+86.csv
# (48, 63)
# dataset1/1/001+62.csv
# (49, 63)
# dataset1/1/002+30.csv
# (47, 63)
# dataset1/1/002+119.csv
# (52, 63)
# dataset1/1/002+185.csv
# (52, 63)
# dataset1/1/001+77.csv
# (48, 63)
# dataset1/1/002+31.csv
# (47, 63)
# dataset1/1/002+159.csv
# (37, 63)
# dataset1/1/002+54.csv
# (54, 63)
# dataset1/1/002+18.csv
# (39, 63)
# dataset1/1/ne-7.csv
# (52, 63)
# dataset1/1/39.csv
# (54, 63)
# dataset1/1/002+133.csv
# (48, 63)
# dataset1/1/002+193.csv
# (52, 63)
# dataset1/1/37.csv
# (54, 63)
# dataset1/1/002+210.csv
# (45, 63)
# dataset1/1/002+209.csv
# (52, 63)
# dataset1/1/001+85.csv
# (54, 63)
# dataset1/1/001-3.csv
# (38, 63)
# dataset1/1/002+161.csv
# (37, 63)
# dataset1/1/002+41.csv
# (43, 63)
# dataset1/1/001+90.csv
# (53, 63)
# dataset1/1/002+220.csv
# (52, 63)
# dataset1/1/001+46.csv
# (54, 63)
# dataset1/1/002+207.csv
# (57, 63)
# dataset1/1/002+45.csv
# (43, 63)
# dataset1/1/002+123.csv
# (42, 63)
# dataset1/1/0001-18.csv
# (39, 63)
# dataset1/1/no-2.csv
# (36, 63)
# dataset1/1/83.csv
# (53, 63)
# dataset1/1/002-7.csv
# (43, 63)
# dataset1/1/002+180.csv
# (52, 63)
# dataset1/1/94.csv
# (50, 63)
# dataset1/1/001+52.csv
# (37, 63)
# dataset1/1/002+21.csv
# (42, 63)
# dataset1/1/002+105.csv
# (50, 63)
# dataset1/1/001+96.csv
# (52, 63)
# dataset1/1/49.csv
# (52, 63)
# dataset1/1/001+103.csv
# (43, 63)
# dataset1/1/001+107.csv
# (46, 63)
# dataset1/1/002+173.csv
# (53, 63)
# dataset1/1/002+141.csv
# (43, 63)
# dataset1/1/001+100.csv
# (45, 63)
# dataset1/1/002+19.csv
# (38, 63)
# dataset1/1/002-8.csv
# (39, 63)
# dataset1/1/001+5.csv
# (40, 63)
# dataset1/1/002+79.csv
# (53, 63)
# dataset1/1/00-6.csv
# (40, 63)
# dataset1/1/002+64.csv
# (52, 63)
# dataset1/1/002-4.csv
# (39, 63)
# dataset1/1/68.csv
# (52, 63)
# dataset1/1/001+76.csv
# (35, 63)
# dataset1/1/001+34.csv
# (43, 63)
# dataset1/1/0001-19.csv
# (38, 63)
# dataset1/1/71.csv
# (39, 63)
# dataset1/1/001+110.csv
# (52, 63)
# dataset1/1/0001-5.csv
# (40, 63)
# dataset1/1/001+19.csv
# (47, 63)
# dataset1/1/001+28.csv
# (43, 63)
# dataset1/1/97.csv
# (46, 63)
# dataset1/1/002+82.csv
# (46, 63)
# dataset1/1/002+71.csv
# (34, 63)
# dataset1/1/002+158.csv
# (37, 63)
# dataset1/1/002+70.csv
# (51, 63)
# dataset1/1/98.csv
# (47, 63)
# dataset1/1/002+188.csv
# (39, 63)
# dataset1/1/002+2.csv
# (36, 63)
# dataset1/1/004-10.csv
# (46, 63)
# dataset1/1/002+195.csv
# (54, 63)
# dataset1/1/002+176.csv
# (44, 63)
# dataset1/1/001+55.csv
# (52, 63)
# dataset1/1/002+150.csv
# (46, 63)
# dataset1/1/64.csv
# (43, 63)
# dataset1/1/002+81.csv
# (43, 63)
# dataset1/1/002+75.csv
# (52, 63)
# dataset1/1/002+22.csv
# (42, 63)
# dataset1/1/001+16.csv
# (52, 63)
# dataset1/1/002+37.csv
# (48, 63)
# dataset1/1/44.csv
# (37, 63)
# dataset1/1/001+94.csv
# (49, 63)
# dataset1/1/22.csv
# (43, 63)
# dataset1/1/001+13.csv
# (42, 63)
# dataset1/1/51.csv
# (40, 63)
# dataset1/1/002+153.csv
# (54, 63)
# dataset1/1/0001-20.csv
# (46, 63)
# dataset1/1/002+63.csv
# (52, 63)
# dataset1/1/002+117.csv
# (46, 63)
# dataset1/1/002+9.csv
# (38, 63)
# dataset1/1/001-10.csv
# (46, 63)
# dataset1/1/001+53.csv
# (52, 63)
# dataset1/1/002+16.csv
# (40, 63)
# dataset1/1/002+26.csv
# (52, 63)
# dataset1/1/001+3.csv
# (38, 63)
# dataset1/1/23.csv
# (43, 63)
# dataset1/1/001+15.csv
# (52, 63)
# dataset1/1/002+104.csv
# (49, 63)
# dataset1/1/002+10.csv
# (46, 63)
# dataset1/1/002+73.csv
# (53, 63)
# dataset1/1/002+142.csv
# (43, 63)
# dataset1/1/59.csv
# (44, 63)
# dataset1/1/002+214.csv
# (46, 63)
# dataset1/1/002+137.csv
# (48, 63)
# dataset1/1/002+80.csv
# (52, 63)
# dataset1/1/002+147.csv
# (43, 63)
# dataset1/1/77.csv
# (44, 63)
# dataset1/1/61.csv
# (45, 63)
# dataset1/1/001+27.csv
# (48, 63)
# dataset1/1/002+154.csv
# (54, 63)
# dataset1/1/002+6.csv
# (40, 63)
# dataset1/1/001+59.csv
# (46, 63)
# dataset1/1/002+194.csv
# (44, 63)
# dataset1/1/001+23.csv
# (48, 63)
# dataset1/1/80.csv
# (34, 63)
# dataset1/1/no-6.csv
# (40, 63)
# dataset1/1/002+94.csv
# (44, 63)
# dataset1/1/002+186.csv
# (35, 63)
# dataset1/1/001+79.csv
# (45, 63)
# dataset1/1/002+177.csv
# (45, 63)
# dataset1/1/001+56.csv
# (52, 63)
# dataset1/1/002+39.csv
# (43, 63)
# dataset1/1/001+101.csv
# (50, 63)
# dataset1/1/79.csv
# (48, 63)
# dataset1/1/001+40.csv
# (46, 63)
# dataset1/1/001+65.csv
# (52, 63)
# dataset1/1/002+166.csv
# (52, 63)
# dataset1/1/002+139.csv
# (43, 63)
# dataset1/1/002+50.csv
# (46, 63)
# dataset1/1/001+14.csv
# (42, 63)
# dataset1/1/0001-9.csv
# (38, 63)
# dataset1/1/76.csv
# (52, 63)
# dataset1/1/001+95.csv
# (50, 63)
# dataset1/1/96.csv
# (43, 63)
# dataset1/1/001-8.csv
# (39, 63)
# dataset1/1/0001-10.csv
# (46, 63)
# dataset1/1/002+65.csv
# (52, 63)
# dataset1/1/00-4.csv
# (39, 63)
# dataset1/1/002+151.csv
# (46, 63)
# dataset1/1/001+29.csv
# (43, 63)
# dataset1/1/21.csv
# (43, 63)
# dataset1/1/001+44.csv
# (54, 63)
# dataset1/1/001+10.csv
# (46, 63)
# dataset1/1/002+206.csv
# (52, 63)
# dataset1/1/002+32.csv
# (47, 63)
# dataset1/1/002+136.csv
# (48, 63)
# dataset1/1/16.csv
# (48, 63)
# dataset1/1/002+155.csv
# (54, 63)
# dataset1/1/002+200.csv
# (53, 63)
# dataset1/1/25.csv
# (43, 63)
# dataset1/1/0001-2.csv
# (36, 63)
# dataset1/1/001-4.csv
# (39, 63)
# dataset1/1/001+45.csv
# (54, 63)
# dataset1/1/no-3.csv
# (38, 63)
# dataset1/1/00-3.csv
# (38, 63)
# dataset1/1/81.csv
# (45, 63)
# dataset1/1/002+187.csv
# (48, 63)
# dataset1/1/2.csv
# (42, 63)
# dataset1/1/002+78.csv
# (45, 63)
# dataset1/1/001+63.csv
# (53, 63)
# dataset1/1/001+67.csv
# (45, 63)
# dataset1/1/004-3.csv
# (38, 63)
# dataset1/1/15.csv
# (47, 63)
# dataset1/1/53.csv
# (51, 63)
# dataset1/1/0001-17.csv
# (43, 63)
# dataset1/1/002+42.csv
# (43, 63)
# dataset1/1/35.csv
# (46, 63)
# dataset1/1/002+23.csv
# (42, 63)
# dataset1/1/0001-3.csv
# (38, 63)
# dataset1/1/67.csv
# (49, 63)
# dataset1/1/002+125.csv
# (52, 63)
# dataset1/1/57.csv
# (52, 63)
# dataset1/1/001+72.csv
# (46, 63)
# dataset1/1/002+168.csv
# (40, 63)
# dataset1/1/004-6.csv
# (40, 63)
# dataset1/1/002+107.csv
# (57, 63)
# dataset1/1/002+144.csv
# (43, 63)
# dataset1/1/002+120.csv
# (52, 63)
# dataset1/1/00-2.csv
# (36, 63)
# dataset1/1/4.csv
# (42, 63)
# dataset1/1/002+171.csv
# (34, 63)
# dataset1/1/0001-7.csv
# (43, 63)
# dataset1/1/002+91.csv
# (45, 63)
# dataset1/1/002+146.csv
# (43, 63)
# dataset1/1/001+109.csv
# (52, 63)
# dataset1/1/001+36.csv
# (43, 63)
# dataset1/1/11.csv
# (47, 63)
# dataset1/1/002+103.csv
# (47, 63)
# dataset1/1/36.csv
# (54, 63)
# dataset1/1/50.csv
# (52, 63)
# dataset1/1/88.csv
# (50, 63)
# dataset1/1/60.csv
# (45, 63)
# dataset1/1/no-1.csv
# (38, 63)
# dataset1/1/002+12.csv
# (36, 63)
# dataset1/1/002+181.csv
# (43, 63)
# dataset1/1/002+134.csv
# (48, 63)
# dataset1/1/001+102.csv
# (50, 63)
# dataset1/1/001+24.csv
# (48, 63)
# dataset1/1/002+88.csv
# (39, 63)
# dataset1/1/002+55.csv
# (54, 63)
# dataset1/1/00-9.csv
# (38, 63)
# dataset1/1/002+100.csv
# (53, 63)
# dataset1/1/002+149.csv
# (46, 63)
# dataset1/1/002+145.csv
# (43, 63)
# dataset1/1/12.csv
# (47, 63)
# dataset1/1/002+48.csv
# (46, 63)
# dataset1/1/001+4.csv
# (39, 63)
# dataset1/1/002+189.csv
# (45, 63)
# dataset1/1/002+196.csv
# (48, 63)
# dataset1/1/002+87.csv
# (48, 63)
# dataset1/1/001+57.csv
# (52, 63)
# dataset1/1/002+95.csv
# (54, 63)
# dataset1/1/002+192.csv
# (53, 63)
# dataset1/1/002+130.csv
# (47, 63)
# dataset1/1/56.csv
# (53, 63)
# dataset1/1/002+38.csv
# (43, 63)
# dataset1/1/002+109.csv
# (52, 63)
# dataset1/1/002+128.csv
# (47, 63)
# dataset1/1/002+102.csv
# (50, 63)
# dataset1/1/002+57.csv
# (54, 63)
# dataset1/1/002+92.csv
# (53, 63)
# dataset1/1/0001-12.csv
# (36, 63)
# dataset1/1/002+172.csv
# (49, 63)
# dataset1/1/no-4.csv
# (39, 63)
# dataset1/1/001+22.csv
# (47, 63)
# dataset1/1/85.csv
# (50, 63)
# dataset1/1/002+198.csv
# (45, 63)
# dataset1/1/34.csv
# (46, 63)
# dataset1/1/002+61.csv
# (37, 63)
# dataset1/1/00-10.csv
# (46, 63)
# dataset1/1/001+83.csv
# (52, 63)
# dataset1/1/002+167.csv
# (52, 63)
# dataset1/1/004-2.csv
# (36, 63)
# dataset1/1/002+178.csv
# (45, 63)
# dataset1/1/002+24.csv
# (42, 63)
# dataset1/1/002+138.csv
# (43, 63)
# dataset1/1/002+40.csv
# (43, 63)
# dataset1/1/002+51.csv
# (46, 63)
# dataset1/1/20.csv
# (48, 63)
# dataset1/1/002+163.csv
# (52, 63)
# dataset1/1/001+2.csv
# (36, 63)
# dataset1/1/33.csv
# (46, 63)
# dataset1/1/001+8.csv
# (39, 63)
# dataset1/1/38.csv
# (54, 63)
# dataset1/1/001+41.csv
# (46, 63)
# dataset1/1/99.csv
# (46, 63)
# dataset1/1/19.csv
# (48, 63)
# dataset1/1/002+1.csv
# (38, 63)
# dataset1/1/002+140.csv
# (43, 63)
# dataset1/1/002+204.csv
# (49, 63)
# dataset1/1/27.csv
# (43, 63)
# dataset1/1/002+157.csv
# (54, 63)
# dataset1/1/002+86.csv
# (35, 63)
# dataset1/1/004-9.csv
# (38, 63)
# dataset1/1/001+88.csv
# (45, 63)
# dataset1/1/002+58.csv
# (37, 63)
# dataset1/1/002+66.csv
# (52, 63)
# dataset1/1/87.csv
# (49, 63)

# %%
y = np.array(y)
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.3)

# %%
max_review_length = 50
X_train = pad_sequences(X_train, maxlen=max_review_length)
X_test = pad_sequences(X_test, maxlen=max_review_length)

# %%
X_train = X_train.reshape(-1, 50* 63)
X_test = X_test.reshape(-1, 50* 63)

# %%
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
joblib.dump(scaler, 'scaler1.pkl')

# %%
np.save('training_data1.npy', X_train)

# %%
X_train = X_train.reshape(-1, 50, 63)
X_test = X_test.reshape(-1, 50, 63)

# %%
X_train=np.array(X_train)
y_train=np.array(y_train)

# %%
y_train = np.asarray(y_train).astype('float32').reshape((-1,1))
y_test = np.asarray(y_test).astype('float32').reshape((-1,1))

# %%
model = Sequential()
model.add(LSTM(64, input_shape=(50, 63), return_sequences=True))
model.add(LSTM(32, return_sequences=True))
model.add(LSTM(16))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)
history=model.fit(X_train, y_train, epochs=10, batch_size=32, validation_data=(X_test, y_test))

# %%
loss, accuracy = model.evaluate(X_test, y_test)

# %%
print(f"Test Loss: {loss:.4f}")
print(f"Test Accuracy: {accuracy:.4f}")

# %%
y_pred = (model.predict(X_test) > 0.5).astype("int32")

# %%
cm = confusion_matrix(y_test,y_pred)

# %%
print("Confusion Matrix:")
print(cm)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %%
print('Precision: %.3f' % precision_score(y_test, y_pred))

# %%
print('Recall: %.3f' % recall_score(y_test, y_pred))

# %%
print(matthews_corrcoef(y_test, y_pred))

# %%
# roc curve for tpr = fpr 
random_probs = [0 for i in range(len(y_test))]
p_fpr, p_tpr, _ = roc_curve(y_test, random_probs, pos_label=1)

# %%
fpr1, tpr1, thresholds_keras = roc_curve(y_test, y_pred)

# %%
plt.plot(fpr1, tpr1, linestyle='--',color='orange', label='ROC curve')
plt.plot(p_fpr, p_tpr, linestyle='--', color='blue')
# title
plt.title('ROC curve')
# x label
plt.xlabel('False Positive Rate')
# y label
plt.legend(loc='lower right')
plt.ylabel('True Positive rate')

# %%
auc_score1 = roc_auc_score(y_test, y_pred)
print(auc_score1)

# %%
val_loss = history.history['val_loss']
val_accuracy = history.history['val_accuracy']
print(f"Validation Loss: {val_loss}")
print(f"Validation Accuracy: {val_accuracy}")

# %%
train_loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(train_loss) + 1)

plt.plot(epochs, train_loss, 'g', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
save_model(model, 'your_model1.h5')
